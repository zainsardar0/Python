# %%
import numpy as np

def gini_impurity(y):
    m = len(y)
    if m == 0:
        return 0
    _, counts = np.unique(y, return_counts=True)
    p = counts / m
    return 1 - np.sum(p ** 2)

def entropy(y):
    m = len(y)
    if m == 0:
        return 0
    _, counts = np.unique(y, return_counts=True)
    p = counts / m
    return -np.sum(p * np.log2(p))

def most_common_label(y):
    return np.bincount(y).argmax()

# %%
class Node:
    def __init__(self, feature=None, threshold=None, left=None, right=None, value=None):
        self.feature = feature
        self.threshold = threshold
        self.left = left
        self.right = right
        self.value = value

# %%
class DecisionTree:
    def __init__(self, max_depth=None, min_samples_split=2, criterion='gini'):
        self.max_depth = max_depth
        self.min_samples_split = min_samples_split
        self.criterion = gini_impurity if criterion == 'gini' else entropy
        self.root = None

    def fit(self, X, y):
        self.root = self._grow_tree(X, y)

    def _grow_tree(self, X, y, depth=0):
        num_samples, num_features = X.shape
        if num_samples >= self.min_samples_split and (self.max_depth is None or depth < self.max_depth):
            best_feature, best_threshold = self._best_split(X, y)
            if best_feature is not None:
                left_idxs, right_idxs = self._split(X[:, best_feature], best_threshold)
                left = self._grow_tree(X[left_idxs, :], y[left_idxs], depth + 1)
                right = self._grow_tree(X[right_idxs, :], y[right_idxs], depth + 1)
                return Node(feature=best_feature, threshold=best_threshold, left=left, right=right)
        return Node(value=most_common_label(y))

    def _best_split(self, X, y):
        num_samples, num_features = X.shape
        if num_samples <= 1:
            return None, None

        best_gain = -1
        best_feature, best_threshold = None, None

        for feature in range(num_features):
            thresholds, classes = zip(*sorted(zip(X[:, feature], y)))
            num_left = [0] * len(set(y))
            num_right = np.bincount(classes)

            for i in range(1, num_samples):
                c = classes[i - 1]
                num_left[c] += 1
                num_right[c] -= 1

                gain = self._information_gain(y, num_left, num_right, i)

                if thresholds[i] == thresholds[i - 1]:
                    continue

                if gain > best_gain:
                    best_gain = gain
                    best_feature = feature
                    best_threshold = (thresholds[i] + thresholds[i - 1]) / 2

        return best_feature, best_threshold

    def _information_gain(self, y, num_left, num_right, split_idx):
        num = len(y)
        p_left = split_idx / num
        p_right = 1 - p_left
        impurity = self.criterion(y)
        left_impurity = self.criterion(num_left)
        right_impurity = self.criterion(num_right)
        return impurity - (p_left * left_impurity + p_right * right_impurity)

    def _split(self, X_column, split_threshold):
        left_idxs = np.argwhere(X_column <= split_threshold).flatten()
        right_idxs = np.argwhere(X_column > split_threshold).flatten()
        return left_idxs, right_idxs

    def predict(self, X):
        return np.array([self._predict(inputs) for inputs in X])

    def _predict(self, inputs):
        node = self.root
        while node.value is None:
            if inputs[node.feature] <= node.threshold:
                node = node.left
            else:
                node = node.right
        return node.value

# %%
# Generate some example data
np.random.seed(0)
X = np.random.rand(100, 2)
y = (X[:, 0] + X[:, 1] > 1).astype(int)

# Initialize and train the decision tree model
dt_model = DecisionTree(max_depth=3)
dt_model.fit(X, y)

# Make predictions
predictions = dt_model.predict(X)

# Print the accuracy
accuracy = np.mean(predictions == y)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 8
#       6 # Initialize and train the decision tree model
#       7 dt_model = DecisionTree(max_depth=3)
# ----> 8 dt_model.fit(X, y)
#      10 # Make predictions
#      11 predictions = dt_model.predict(X)
#
# Cell In[4], line 9, in DecisionTree.fit(self, X, y)
#       8 def fit(self, X, y):
# ----> 9     self.root = self._grow_tree(X, y)
#
# Cell In[4], line 18, in DecisionTree._grow_tree(self, X, y, depth)
#      16         left_idxs, right_idxs = self._split(X[:, best_feature], best_threshold)
#      17         left = self._grow_tree(X[left_idxs, :], y[left_idxs], depth + 1)
# ---> 18         right = self._grow_tree(X[right_idxs, :], y[right_idxs], depth + 1)
#      19         return Node(feature=best_feature, threshold=best_threshold, left=left, right=right)
#      20 return Node(value=most_common_label(y))
#
# Cell In[4], line 14, in DecisionTree._grow_tree(self, X, y, depth)
#      12 num_samples, num_features = X.shape
#      13 if num_samples >= self.min_samples_split and (self.max_depth is None or depth < self.max_depth):
# ---> 14     best_feature, best_threshold = self._best_split(X, y)
#      15     if best_feature is not None:
#      16         left_idxs, right_idxs = self._split(X[:, best_feature], best_threshold)
#
# Cell In[4], line 37, in DecisionTree._best_split(self, X, y)
#      35 for i in range(1, num_samples):
#      36     c = classes[i - 1]
# ---> 37     num_left[c] += 1
#      38     num_right[c] -= 1
#      40     gain = self._information_gain(y, num_left, num_right, i)
#
# IndexError: list index out of range
